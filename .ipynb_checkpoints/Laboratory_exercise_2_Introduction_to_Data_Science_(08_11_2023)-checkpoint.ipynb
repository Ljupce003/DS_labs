# %% [markdown]
# # Requirements

# %%
import pandas as pd
import missingno as msno
from sklearn.neighbors import KNeighborsClassifier
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer,KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# !pip install missingno
# Out:
# Requirement already satisfied: missingno in c:\users\ljupce\anaconda3\lib\site-packages (0.5.2)
# Requirement already satisfied: numpy in c:\users\ljupce\anaconda3\lib\site-packages (from missingno) (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\ljupce\anaconda3\lib\site-packages (from missingno) (3.9.2)
# Requirement already satisfied: scipy in c:\users\ljupce\anaconda3\lib\site-packages (from missingno) (1.13.1)
# Requirement already satisfied: seaborn in c:\users\ljupce\anaconda3\lib\site-packages (from missingno) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ljupce\anaconda3\lib\site-packages (from matplotlib->missingno) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ljupce\anaconda3\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ljupce\anaconda3\lib\site-packages (from matplotlib->missingno) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ljupce\anaconda3\lib\site-packages (from matplotlib->missingno) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ljupce\anaconda3\lib\site-packages (from matplotlib->missingno) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\ljupce\anaconda3\lib\site-packages (from matplotlib->missingno) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ljupce\anaconda3\lib\site-packages (from matplotlib->missingno) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ljupce\anaconda3\lib\site-packages (from matplotlib->missingno) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\ljupce\anaconda3\lib\site-packages (from seaborn->missingno) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ljupce\anaconda3\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ljupce\anaconda3\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\ljupce\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\ljupce\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\ljupce\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\ljupce\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ljupce\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ljupce\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\ljupce\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\ljupce\anaconda3\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\ljupce\anaconda3\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\ljupce\anaconda3\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ljupce\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ljupce\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ljupce\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ljupce\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ljupce\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\ljupce\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ljupce\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ljupce\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ljupce\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ljupce\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\ljupce\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
# !pip install numpy
# !pip install matplotlib
# Out:
# Requirement already satisfied: numpy in c:\users\ljupce\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\ljupce\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ljupce\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ljupce\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ljupce\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ljupce\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\ljupce\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ljupce\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\ljupce\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ljupce\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ljupce\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ljupce\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
# Add as many imports as you need.

# %% [markdown]
# # Laboratory Exercise - Run Mode (8 points)

# %% [markdown]
# ## Introduction
# Mammography is the most effective method for breast cancer screening available today. However, the low positive predictive value of breast biopsy resulting from mammogram interpretation leads to approximately 70% unnecessary biopsies with benign outcomes. To reduce the high number of unnecessary breast biopsies, several computer-aided diagnosis (CAD) systems have been proposed in the last years.These system help physicians in their decision to perform a breast biopsy on a suspicious lesion seen in a mammogram or to perform a short term follow-up examination instead. This data set can be used to predict the severity (benign or malignant) of a mammographic mass lesion from BI-RADS attributes and the patient's age. It contains a BI-RADS assessment, the patient's age and three BI-RADS attributes together with the ground truth (the severity field) for 516 benign and 445 malignant masses that have been identified on full field digital mammograms collected at the Institute of Radiology of the University Erlangen-Nuremberg between 2003 and 2006. Each instance has an associated BI-RADS assessment ranging from 1 (definitely benign) to 5 (highly suggestive of malignancy) assigned in a double-review process by physicians. Assuming that all cases with BI-RADS assessments greater or equal a given value (varying from 1 to 5), are malignant and the other cases benign, sensitivities and associated specificities can be calculated. These can be an indication of how well a CAD system performs compared to the radiologists. For more details visit https://archive.ics.uci.edu/dataset/161/mammographic+mass.

# %% [markdown]
# ## The Mammographic Mass Dataset

# %% [markdown]
# ## Downloading the Mammographic Mass Dataset

# %%
pip install --upgrade --no-cache-dir gdown
# Out:
# Collecting gdown
#   Downloading gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\ljupce\anaconda3\lib\site-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in c:\users\ljupce\anaconda3\lib\site-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in c:\users\ljupce\anaconda3\lib\site-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\ljupce\anaconda3\lib\site-packages (from gdown) (4.66.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ljupce\anaconda3\lib\site-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ljupce\anaconda3\lib\site-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ljupce\anaconda3\lib\site-packages (from requests[socks]->gdown) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ljupce\anaconda3\lib\site-packages (from requests[socks]->gdown) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ljupce\anaconda3\lib\site-packages (from requests[socks]->gdown) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\ljupce\anaconda3\lib\site-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: colorama in c:\users\ljupce\anaconda3\lib\site-packages (from tqdm->gdown) (0.4.6)
# Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Installing collected packages: gdown
# Successfully installed gdown-5.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# !gdown 1CyiAL5d2jJHvpzt3XaY3dTto9c2d_h5R
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1CyiAL5d2jJHvpzt3XaY3dTto9c2d_h5R
# To: C:\Users\Ljupce\Documents\Python Codes\DS_lab2\mammographic-mass.csv
#
#   0%|          | 0.00/13.3k [00:00<?, ?B/s]
# 100%|##########| 13.3k/13.3k [00:00<?, ?B/s]

# %% [markdown]
# ## Exploring the Mammographic Mass Dataset
# The Mammographic Mass dataset contains six attributes, among which there is a target attribute and a non-predictive attribute. The target attribute, denoted as 'Severity', is binomial, distinguishing between benign (0) and malignant (1) cases. The non-predictive attribute, 'BI-RADS assessment', is an ordinal scale ranging from 1 to 5. The remaining four attributes are predictive, including 'Age', represented in years as an integer, 'Shape' categorizing mass shape as round (1), oval (2), lobular (3), or irregular (4). 'Margin' classifies mass margins into circumscribed (1), microlobulated (2), obscured (3), ill-defined (4), or spiculated (5). 'Density' indicates mass density as high (1), iso (2), low (3), or fat-containing (4).

# %% [markdown]
# Load the dataset into a `pandas` data frame.

# %%
data=pd.read_csv("./mammographic-mass.csv")

# %%
# Write your code here. Add as many boxes as you need.

# %%
data
# Out:
#      BI-RADS assessment   Age  Shape  Margin  Density  Severity
# 0                   5.0  67.0    3.0     5.0      3.0         1
# 1                   4.0  43.0    1.0     1.0      NaN         1
# 2                   5.0  58.0    4.0     5.0      3.0         1
# 3                   4.0  28.0    1.0     1.0      3.0         0
# 4                   5.0  74.0    1.0     5.0      NaN         1
# ..                  ...   ...    ...     ...      ...       ...
# 956                 4.0  47.0    2.0     1.0      3.0         0
# 957                 4.0  56.0    4.0     5.0      3.0         1
# 958                 4.0  64.0    4.0     5.0      3.0         0
# 959                 5.0  66.0    4.0     5.0      3.0         1
# 960                 4.0  62.0    3.0     3.0      3.0         0
#
# [961 rows x 6 columns]

# %% [markdown]
# Drop the column `BI-RADS assessment` as it shouldn't be used for prediction.

# %%
data=data.drop('BI-RADS assessment',axis=1)

# %%
data.columns
# Out:
# Index(['Age', 'Shape', 'Margin', 'Density', 'Severity'], dtype='object')

# %%
plt.hist(data.Density)
plt.show()

# %%
sns.displot(data.Age,bins=30,kde=True)
plt.show()

# %%
sns.heatmap(data.corr(),annot=True)
plt.show()

# %%
# Write your code here. Add as many boxes as you need.

# %% [markdown]
# Explore the dataset using visualizations of your choice.

# %%
# Write your code here. Add as many boxes as you need.

# %% [markdown]
# Check if the dataset is balanced.

# %%
# Write your code here. Add as many boxes as you need.

# %%
plt.hist(data.Density,bins=10)
plt.show()
#This is a column with numbers but they are repeated. Best for this is to impute the mode

# %% [markdown]
# ## Detecting Missing Values
# Calculate the percentage of missing values present in each column of the dataset.

# %%
# Write your code here. Add as many boxes as you need.

# %%
miss_num_data=data.isnull().sum()

# %%
miss_perc = miss_num_data / len(data) * 100

# %% [markdown]
# ## Understanding the Causes Behind Missing Values
# Using visualization tools such as heatmaps, and dendrograms, illustrate the interdependence between attributes with missing values. Also, visualize the distribution of the missing values within the dataset using matrices and bar charts. To achieve this use the `missingno` library.

# %%
# Write your code here. Add as many boxes as you need.

# %%
msno.dendrogram(data)
plt.show()

# %%
msno.heatmap(data)
plt.show()

# %%
msno.matrix(data)
plt.show()

# %% [markdown]
# ## Handling the Missing Values
# Handle the missing values using suitable method based on the insights obtained from the various visualizations.

# %%
# Write your code here. Add as many boxes as you need.

# %%
miss_perc
# Out:
# Age         0.520291
# Shape       3.225806
# Margin      4.994797
# Density     7.908429
# Severity    0.000000
# dtype: float64

# %%
#Because the Age column has a normal distribuiton and as far as i can see theres no outliers then we can insert the mean for the missing values
data["Age"]=data["Age"].fillna(data['Age'].mean())

# %%
data.isnull().sum()
# Out:
# Age          0
# Shape       31
# Margin      48
# Density     76
# Severity     0
# dtype: int64

# %%
#Because we can see that Shape and Margin have high correlation we can impute them with KNN or MICE
mice=IterativeImputer()
imputed_val = mice.fit_transform(data[["Shape","Margin"]])
data[["Shape","Margin"]]=imputed_val

# %%
sns.heatmap(data.corr(),annot=True)
plt.show()

# %%
data.isnull().sum() / len(data) * 100
# Out:
# Age         0.000000
# Shape       0.000000
# Margin      0.000000
# Density     7.908429
# Severity    0.000000
# dtype: float64

# %%
data.Density=data.Density.fillna(data.Density.mode()[0])

# %%
data.isnull().sum() / len(data) * 100
# Out:
# Age         0.0
# Shape       0.0
# Margin      0.0
# Density     0.0
# Severity    0.0
# dtype: float64

# %% [markdown]
# ## Dataset Splitting
# Partition the dataset into training and testing sets with an 80:20 ratio.

# %%
X=data.drop("Severity",axis=1)
Y=data["Severity"]

x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2)

# %%
# Write your code here. Add as many boxes as you need.

# %% [markdown]
# ## Feature Scaling
# Standardize the features using `StandardScaler`.

# %%
# Write your code here. Add as many boxes as you need.

# %%
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %% [markdown]
# ## K-Nearset Neighbors Classification

# %% [markdown]
# Create an instance of the KNN Classification model and train it using the `fit` function.

# %%
# Write your code here. Add as many boxes as you need.

# %%
from sklearn.neighbors import KNeighborsClassifier
plt.hist(data.Severity)
plt.show()

# %%
#Because it is Categorical data we use A classifier,NOT a regressor

# %%
model=KNeighborsClassifier(n_neighbors=6)
# Out:
# KNeighborsClassifier(n_neighbors=6)

# %% [markdown]
# Use the trained model to make predictions for the test set.

# %%
# Write your code here. Add as many boxes as you need.

# %%
model.fit(x_train,y_train)

y_pred=model.predict(x_test)

# %% [markdown]
# Assess the performance of the model by using different classification metrics provided by the `scikit-learn` library.

# %%
# Write your code here. Add as many boxes as you need.

# %%
from sklearn.metrics import r2_score,f1_score,mean_squared_error

# %%
r2_score(y_test,y_pred)
# Out:
# 0.0030133448127421802

# %%
f1_score(y_test,y_pred)
# Out:
# 0.7073170731707317

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.24870466321243523

# %%
f1_scores=[]
maxim=0
max_i=0
for i in range(3,15):
    it_model=KNeighborsClassifier(n_neighbors=i)
    it_model.fit(x_train,y_train)
    y_pred = it_model.predict(x_test)
    f_score=f1_score(y_test,y_pred)
    f1_scores.append(f_score)
    if f_score > maxim :
        maxim=f_score
        max_i=i

# %%
plt.plot([i for i in range(3,15)],f1_scores)

# %% [markdown]
# # Laboratory Exercise - Bonus Task (+ 2 points)

# %% [markdown]
# As part of the bonus task in this laboratory assignment, your objective is to fine-tune the number of neighbors (`n_neighbors`) using a validation set. This involves experimenting with various values for `n_neighbors` and evaluating the model's performance on a validation set. Subsequently, you're required to generate a line plot illustrating how the F1 score of the model predictions changes with different `n_neighbors` values. Upon determining the most suitable `n_neighbors` value, evaluate the model's performance on a test set for final assessment.

# %% [markdown]
# ## Dataset Splitting
# To achieve the required split of the dataset into three sets (train set, validation set, and test set) in a ratio of 70:10:20, you can follow these steps:
#
# - Start by splitting the dataset into a ratio of 80:20 to create the initial train and test sets.
# - Subsequently, divide the initial train set further into a ratio of 87.5:12.5 to generate the final train and validation sets.
#
# This process can be accomplished using appropriate functions from libraries such as `scikit-learn` or manually.

# %%
# Write your code here. Add as many boxes as you need.

# %%
# from sklearn.model_selection import GridSearchCV

# params={
#     'n_neighbors': [i for i in range(3,13)]
# }
# cv_modelce=KNeighborsClassifier()
# #cv_modelce.fit(x_train,y_train)
# cv=GridSearchCV(estimator=cv_modelce,param_grid=params,scoring='f1',cv=10)
# cv.fit(x_train,y_train)

# najdobar_model = cv.best_estimator_

# cv.best_score_

x_train_final,x_valid,y_train_final,y_valid = train_test_split(x_train,y_train,test_size=0.125)

# %% [markdown]
# ## Fine-tuning the K-Nearset Neighbors Hyperparameter
# Experiment with various values for `n_neighbors` and evaluate the model's performance on the validation set.

# %%
# Write your code here. Add as many boxes as you need.

# %%
f1_scores=[]
maxim=0
max_i=0
for i in range(3,15):
    it_model=KNeighborsClassifier(n_neighbors=i)
    it_model.fit(x_train_final,y_train_final)
    y_pred = it_model.predict(x_test)
    f_score=f1_score(y_test,y_pred)
    f1_scores.append(f_score)
    if f_score > maxim :
        maxim=f_score
        max_i=i

# %% [markdown]
# ## Dependence of the Model Performance on the KNN Hyperparameter
# Generate a line plot illustrating how the F1 score of the model predictions changes with different `n_neighbors` values.

# %%
# Write your code here. Add as many boxes as you need.

# %%
plt.plot([i for i in range(3,15)],f1_scores)
plt.show()

# %% [markdown]
# ## Final Assessment of the Model Performance
# Upon determining the most suitable `n_neighbors` value, evaluate the model's performance on a test set for final assessment.

# %%
# Write your code here. Add as many boxes as you need.

# %%
max_i #THis is the best parameter value for n_neighbours
# Out:
# 13

# %%
bestKNN=KNeighborsClassifier(n_neighbors=max_i)
bestKNN.fit(x_train_final,y_train_final)

y_final_pred=bestKNN.predict(x_valid)

f1_score(y_valid,y_final_pred)
# Out:
# 0.7755102040816326
